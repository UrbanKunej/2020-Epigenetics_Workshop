# %% [markdown]
# #Pharokka + Phold + Phynteny
#
# [pharokka](https://github.com/gbouras13/pharokka) is a rapid standardised annotation tool for bacteriophage genomes and metagenomes. You can read more about pharokka in the [documentation](https://pharokka.readthedocs.io/).
#
# [phold](https://github.com/gbouras13/phold) is a sensitive annotation tool for bacteriophage genomes and metagenomes using protein structural homology. You can read more about phold in the [documentation](https://phold.readthedocs.io/).
#
# phold uses the [ProstT5](https://github.com/mheinzinger/ProstT5) protein language model to translate protein amino acid sequences to the 3Di token alphabet used by [Foldseek](https://github.com/steineggerlab/foldseek). Foldseek is then used to search these against a database of 803k protein structures mostly predicted using [Colabfold](https://github.com/sokrypton/ColabFold).
#
# [phyntney](https://github.com/susiegriggo/Phynteny_transformer) uses phage synteny (the conserved gene order across phages) with a hybrid transformer/LSTM architecture to assign hypothetical phage proteins to a PHROG category.
#
# The tools are best run sequentially, as Pharokka conducts extra annotation steps like tRNA, tmRNA, CRISPR and INPHARED searches that Phold lacks (for now at least). Pharokka will also (rarely) annotate CDS that Phold can miss. Phynteny can then help annotate remaining hypothetical proteins with a PHROG category.
#
# * **Before you start, please make sure you change the runtime to T4 GPU (or any other kind of GPU if you have $$$), otherwise Phold won't be installed properly**
# * To do this, go to the top toolbar, then to Runtime -> Change runtime type -> Hardware accelerator
#
# * To run the cells, press the play button on the left side
# * Cells 1, 2 and 3 install pharokka, phold and phyntney and download the databases/models.
# * Once they have been run, you can re-run Cell 4 (to run Pharokka), Cell 5 (to run Phold) and Cell 6 (to run Phynteny) as many times as you would like

# %%
#@title 1. Install miniforge

#@markdown This cell installs miniforge

# %%bash

set -e

PYTHON_VERSION=$(python3 -c "import sys; print(f'{sys.version_info.major}.{sys.version_info.minor}')")

echo "python version ${PYTHON_VERSION}"

if [ ! -f CONDA_READY ]; then
  echo "installing miniforge"

  # miniforge 25.9.1 introduces some issue - latest as of 7 Nov 2025 - see https://github.com/gbouras13/phold/issues/106
  # issue is fixed if you use the previous release (25.3.1)
  #wget -qnc https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
  wget -qnc https://github.com/conda-forge/miniforge/releases/download/25.3.1-0/Miniforge3-25.3.1-0-Linux-x86_64.sh
  bash Miniforge3-25.3.1-0-Linux-x86_64.sh -bfp /usr/local 2>&1 1>/dev/null
  conda config --set auto_update_conda false
  touch CONDA_READY
fi

pip install --upgrade matplotlib matplotlib-inline
# Out:
# python version 3.12
# installing miniforge
# warning  libmamba [python-3.12.11-h9e4cc4f_0_cpython] The following files were already present in the environment:
#     - bin/python
# warning  libmamba [charset-normalizer-3.4.2-pyhd8ed1ab_0] The following files were already present in the environment:
#     - bin/normalizer
# warning  libmamba [distro-1.9.0-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/distro
# warning  libmamba [jsonpointer-3.0.0-py312h7900ff3_1] The following files were already present in the environment:
#     - bin/jsonpointer
# warning  libmamba [wheel-0.45.1-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/wheel
# warning  libmamba [jsonpatch-1.33-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/jsondiff
#     - bin/jsonpatch
# warning  libmamba [pip-25.1.1-pyh8b19718_0] The following files were already present in the environment:
#     - bin/pip
#     - bin/pip3
# warning  libmamba [tqdm-4.67.1-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/tqdm
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting traitlets (from matplotlib-inline)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 96.4 MB/s eta 0:00:00
# Downloading matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 142.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.4 MB/s eta 0:00:00
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 141.3 MB/s eta 0:00:00
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 124.1 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Installing collected packages: traitlets, six, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, python-dateutil, matplotlib-inline, contourpy, matplotlib
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.9 matplotlib-inline-0.2.1 numpy-2.4.4 pillow-12.2.0 pyparsing-3.3.2 python-dateutil-2.9.0.post0 six-1.17.0 traitlets-5.14.3

# %%
#@title 2. Install pharokka and phold and phynteny

#@markdown This cell installs pharokka and phold. It will take a few minutes. Please be patient

PHAROKKA_VERSION="1.9.1"
PHOLD_VERSION="1.2.2"
PHYNTENY_VERSION="0.1.3"

# add paths
import sys
sys.path.append("/usr/local/bin")

# Update environment variables for shell usage
import os
os.environ["PATH"] = "/usr/local/bin:" + os.environ["PATH"]

# create envs
# pharokka isn't compatible with Python 3.13 (Google Colab default)
# so it needs a separate env
from pathlib import Path
flag_file = Path("PHAROKKA_PHOLD_PHYNTENY_READY")
if not flag_file.exists():
  # !conda install -y -c bioconda phold=={PHOLD_VERSION} pharokka=={PHAROKKA_VERSION} pytorch=*=cuda* phynteny_transformer=={PHYNTENY_VERSION}
  # Touch the flag file
  flag_file.touch()
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  66% 0.6599152679719524/1 [00:46<00:01,  4.85s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  24% 0.24176953296111328/1 [00:46<00:16, 21.76s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  78% 0.7846249051298615/1 [00:46<00:01,  5.80s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  79% 0.7891109423554881/1 [00:46<00:00,  4.53s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  68% 0.6809499854820463/1 [00:46<00:01,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  26% 0.2640285692904804/1 [00:46<00:12, 16.64s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  80% 0.8047409005074501/1 [00:46<00:01,  5.60s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  82% 0.81830078055406/1 [00:46<00:00,  4.21s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  29% 0.2948272359097305/1 [00:46<00:08, 11.70s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  70% 0.7010701500569188/1 [00:47<00:01,  5.54s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  82% 0.8227341024029816/1 [00:47<00:01,  5.89s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  84% 0.8424408999081533/1 [00:47<00:00,  4.58s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  32% 0.3194661692051306/1 [00:47<00:06,  9.97s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  72% 0.719622509599983/1 [00:47<00:01,  6.10s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  84% 0.8399186210672532/1 [00:47<00:01,  6.52s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  86% 0.8648567250226685/1 [00:47<00:00,  5.06s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  74% 0.737390966627143/1 [00:47<00:01,  6.06s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  34% 0.3417252055344977/1 [00:47<00:05,  8.62s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  86% 0.8555868586729126/1 [00:47<00:00,  6.69s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  76% 0.7572498303633808/1 [00:47<00:01,  5.81s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  89% 0.8853019281490945/1 [00:47<00:00,  5.36s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  36% 0.36328427216797277/1 [00:47<00:04,  7.69s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  87% 0.8707496692590346/1 [00:47<00:00,  6.85s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  78% 0.778415198292792/1 [00:47<00:01,  5.56s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  91% 0.9061166228982871/1 [00:47<00:00,  5.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  39% 0.38876316909844333/1 [00:47<00:03,  6.54s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  89% 0.8855081382295268/1 [00:47<00:00,  7.41s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  80% 0.7986660132869818/1 [00:47<00:01,  5.37s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  93% 0.9268081537732242/1 [00:47<00:00,  5.32s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  41% 0.4136820902722002/1 [00:47<00:03,  5.86s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  90% 0.8997611801804815/1 [00:47<00:00,  7.51s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  82% 0.8247960971504524/1 [00:47<00:00,  4.84s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  95% 0.9492239788877395/1 [00:47<00:00,  5.13s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  44% 0.44490073870898555/1 [00:47<00:02,  5.03s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  92% 0.9160359302095858/1 [00:47<00:00,  7.10s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  85% 0.8458308146605464/1 [00:47<00:00,  5.13s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  47% 0.4695396720043856/1 [00:47<00:02,  4.87s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  97% 0.9689301987686318/1 [00:47<00:00,  5.71s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  94% 0.9355454131637295/1 [00:47<00:00,  6.49s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  87% 0.8686946380410833/1 [00:47<00:00,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  49% 0.4947385810564993/1 [00:47<00:02,  4.66s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  99% 0.9880205992782465/1 [00:47<00:00,  5.58s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  95% 0.9527299318280011/1 [00:47<00:00,  6.32s/it]
#
#
#
#
# nccl-2.30.4.1        | 285.6 MB  | : 100% 1.0/1 [00:47<00:00, 11.21s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  90% 0.8986135840647572/1 [00:47<00:00,  4.37s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  52% 0.519937490108613/1 [00:48<00:02,  4.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :   0% 0.00024392465479465442/1 [00:48<54:40:20, 196868.58s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  97% 0.9697122796844578/1 [00:48<00:00,  6.19s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  92% 0.9235678141543717/1 [00:48<00:00,  4.27s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  55% 0.5472363082484029/1 [00:48<00:01,  4.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :   3% 0.027319561337001294/1 [00:48<20:03, 1237.47s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  99% 0.9860881151174696/1 [00:48<00:00,  6.42s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  95% 0.9493059467598903/1 [00:48<00:00,  4.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :   6% 0.06268863628222618/1 [00:48<06:48, 435.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  57% 0.5724352173005166/1 [00:48<00:01,  4.52s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  97% 0.9736069247529181/1 [00:48<00:00,  4.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  11% 0.10976609465759449/1 [00:48<02:54, 196.06s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  60% 0.5958142051433111/1 [00:48<00:01,  4.49s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | : 100% 0.9979079027459459/1 [00:48<00:00,  4.20s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  62% 0.6214330960129599/1 [00:48<00:01,  4.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  15% 0.1465987175315873/1 [00:48<01:44, 122.32s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  65% 0.6450920717341112/1 [00:48<00:01,  4.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  18% 0.18269956644119617/1 [00:48<01:05, 80.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  25% 0.24709567530698492/1 [00:48<00:32, 43.49s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  67% 0.6687510474552624/1 [00:48<00:01,  4.45s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  69% 0.6915700595413431/1 [00:48<00:01,  4.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  29% 0.292221736443996/1 [00:48<00:21, 30.51s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  72% 0.7177489261677057/1 [00:48<00:01,  4.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  33% 0.33368892775908726/1 [00:48<00:14, 22.29s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  74% 0.7409879200713217/1 [00:48<00:01,  4.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  37% 0.37369257114541055/1 [00:48<00:10, 16.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  42% 0.4210139541755735/1 [00:49<00:06, 11.83s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  76% 0.7633869503398673/1 [00:49<00:01,  4.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  47% 0.4671157139317632/1 [00:49<00:04,  8.85s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  78% 0.7849460169733423/1 [00:49<00:01,  4.89s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  81% 0.8080450169377799/1 [00:49<00:00,  4.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  51% 0.5093146792112384/1 [00:49<00:03,  7.36s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  83% 0.8329639381115368/1 [00:49<00:00,  4.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  56% 0.5624902539564731/1 [00:49<00:02,  5.56s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  86% 0.8553629683800823/1 [00:49<00:00,  4.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  60% 0.6029817466523857/1 [00:49<00:01,  4.78s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  88% 0.8772020228919142/1 [00:49<00:00,  4.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  64% 0.642985390038709/1 [00:49<00:01,  4.26s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  90% 0.9000210349779949/1 [00:49<00:00,  4.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  69% 0.6915263963428453/1 [00:49<00:01,  3.56s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  92% 0.9203201561588643/1 [00:49<00:00,  5.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  73% 0.7325057383483472/1 [00:49<00:00,  3.37s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  94% 0.9397793137046633/1 [00:50<00:00,  5.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  77% 0.771533683115492/1 [00:50<00:00,  3.33s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  96% 0.964278253060885/1 [00:50<00:00,  5.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  82% 0.8173915182168869/1 [00:50<00:00,  2.97s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  99% 0.9918570590790317/1 [00:50<00:00,  4.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  86% 0.8569073122936209/1 [00:50<00:00,  2.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  90% 0.9039847706689893/1 [00:50<00:00,  2.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  97% 0.9720397493566979/1 [00:50<00:00,  2.18s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | : 100% 1.0/1 [00:51<00:00,  5.58s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | : 100% 1.0/1 [00:51<00:00,  4.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :   0% 0.0002731843954818996/1 [00:51<52:02:57, 187429.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :   0% 0.00035446419353468044/1 [00:51<40:07:19, 144490.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :   5% 0.052451403932524725/1 [00:51<10:50, 686.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :   5% 0.05139730806252866/1 [00:51<11:04, 700.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  11% 0.11446426170691593/1 [00:51<03:46, 256.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  14% 0.13859549967206006/1 [00:51<02:56, 205.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  17% 0.17155980036263294/1 [00:51<01:56, 141.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  21% 0.20877940999192676/1 [00:51<01:30, 113.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  22% 0.22401120429515767/1 [00:51<01:09, 89.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  28% 0.27612760676351605/1 [00:51<00:51, 71.11s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | : 100% 1.0/1 [00:51<00:00,  6.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  29% 0.28902909041984975/1 [00:51<00:38, 54.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  36% 0.3583632996635619/1 [00:51<00:27, 43.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :   0% 0.000536907561224224/1 [00:51<26:46:59, 96471.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  35% 0.34503189149363916/1 [00:51<00:24, 37.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  43% 0.42961060256403266/1 [00:51<00:16, 29.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :   9% 0.09127428540811808/1 [00:51<06:02, 399.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | : 100% 1.0/1 [00:51<00:00,  2.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  40% 0.399941954985501/1 [00:51<00:15, 26.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :   0% 0.0005983927253209385/1 [00:51<24:06:27, 86839.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  50% 0.5005034412709688/1 [00:51<00:10, 20.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  22% 0.22335354546927716/1 [00:51<01:41, 130.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :   7% 0.06941355613722887/1 [00:52<08:10, 527.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  57% 0.5689150306231621/1 [00:52<00:06, 14.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  35% 0.34845300723452133/1 [00:52<00:44, 68.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  45% 0.4534860964999533/1 [00:52<00:10, 18.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  20% 0.20405191933444003/1 [00:52<01:51, 140.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  64% 0.6383900125559594/1 [00:52<00:03, 10.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  51% 0.5064838692234418/1 [00:52<00:06, 13.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  47% 0.4681833933875233/1 [00:52<00:22, 41.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  31% 0.30697546808964143/1 [00:52<00:54, 78.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  56% 0.5559302448056657/1 [00:52<00:04, 10.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  70% 0.7046748167469447/1 [00:52<00:02,  8.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  62% 0.6158329727241849/1 [00:52<00:09, 25.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  41% 0.40690705321823817/1 [00:52<00:28, 48.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  61% 0.6051034359924076/1 [00:52<00:03,  8.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  77% 0.7677694431961178/1 [00:52<00:01,  6.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  74% 0.7387848042445322/1 [00:52<00:04, 17.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  51% 0.505641852896193/1 [00:52<00:15, 32.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  65% 0.6518179676198125/1 [00:52<00:02,  6.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  83% 0.8269649635164095/1 [00:52<00:00,  5.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  85% 0.8515353921016192/1 [00:52<00:01, 12.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  61% 0.6073686162007526/1 [00:52<00:08, 21.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  90% 0.901756908352227/1 [00:52<00:00,  3.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  70% 0.6985324992472173/1 [00:52<00:01,  5.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  71% 0.7114889504065959/1 [00:52<00:04, 14.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  96% 0.9562323665403428/1 [00:52<00:00,  9.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  96% 0.963788142220796/1 [00:52<00:00,  3.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  74% 0.7430615557107669/1 [00:52<00:01,  4.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  81% 0.8114205355351926/1 [00:52<00:01, 10.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  79% 0.7922347468975088/1 [00:52<00:00,  3.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  91% 0.9071633715865428/1 [00:52<00:00,  7.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  84% 0.8414079380842507/1 [00:52<00:00,  3.26s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | : 100% 1.0/1 [00:53<00:00,  4.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  89% 0.8900347604800288/1 [00:53<00:00,  2.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :   0% 0.0006585779700202317/1 [00:53<22:24:25, 80718.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  97% 0.971443710333635/1 [00:53<00:00,  2.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  15% 0.15344866701471396/1 [00:53<03:26, 243.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  30% 0.30426302214934703/1 [00:53<01:10, 101.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | : 100% 1.0/1 [00:53<00:00,  9.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  45% 0.4537602213439396/1 [00:53<00:30, 56.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | : 100% 1.0/1 [00:53<00:00,  7.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  59% 0.585475815347986/1 [00:53<00:14, 35.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  72% 0.7171914093520323/1 [00:53<00:06, 24.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | : 100% 1.0/1 [00:53<00:00,  3.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  84% 0.835735443955674/1 [00:53<00:02, 17.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  96% 0.9621824141995584/1 [00:53<00:00, 11.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | : 100% 1.0/1 [00:54<00:00,  2.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | : 100% 1.0/1 [00:54<00:00, 11.86s/it]
#
#
# libcublas-12.9.1.4   | 446.1 MB  | : 100% 1.0/1 [00:54<00:00, 12.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libcudnn-9.10.2.21   | 502.4 MB  | : 100% 1.0/1 [01:09<00:00, 11.57s/it]
# libmagma-2.9.0       | 528.8 MB  | : 100% 1.0/1 [01:23<00:00, 11.51s/it]
#
#
#
#
#
# libtorch-2.8.0       | 836.2 MB  | : 100% 1.0/1 [01:57<00:00, 24.00s/it]
#
#
#
#
#
#
#
# triton-3.4.0         | 180.4 MB  | : 100% 1.0/1 [02:04<00:00,  6.85s/it]
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | : 100% 1.0/1 [02:08<00:00,  7.21s/it]
#
#
#
#
# nccl-2.30.4.1        | 285.6 MB  | : 100% 1.0/1 [02:17<00:00, 11.21s/it]
#
#
#
# foldseek-10.941cd33  | 410.2 MB  | : 100% 1.0/1 [02:27<00:00,  9.89s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | : 100% 1.0/1 [02:33<00:00,  4.20s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | : 100% 1.0/1 [02:35<00:00,  6.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | : 100% 1.0/1 [02:37<00:00,  2.18s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | : 100% 1.0/1 [02:39<00:00,  4.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | : 100% 1.0/1 [02:41<00:00,  9.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | : 100% 1.0/1 [02:42<00:00,  7.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | : 100% 1.0/1 [02:43<00:00,  3.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | : 100% 1.0/1 [02:45<00:00,  2.20s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | : 100% 1.0/1 [02:45<00:00,  5.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | : 100% 1.0/1 [02:49<00:00, 11.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
#@title 3. Download pharokka phold databases

#@markdown This cell downloads the pharokka then the phold database. It will take some time (10-15 minutes probably depending on Zenodo's traffic). Please be patient. Perhaps go for a walk or have a coffee or tea.


# %%time

print("Downloading pharokka database. This will take a few minutes. Please be patient :)")
# !install_databases.py -o pharokka_db


print("Downloading phold database. This will take a few minutes. Please be patient :)")
# !phold install -d phold_db -t 8 --foldseek_gpu


print("Downloading phynteny database. This will take a few minutes. Please be patient :)")
# !install_models -o  phynteny_models
# Out:
# Downloading pharokka database. This will take a few minutes. Please be patient :)
# 2026-05-05 05:19:26.626 | INFO     | databases:instantiate_install:124 - Checking Pharokka database installation in pharokka_db.
# 2026-05-05 05:19:26.626 | INFO     | databases:check_db_installation:252 - PHROGs Database file VERSION_1_8_0 is missing.
# 2026-05-05 05:19:26.626 | INFO     | databases:check_db_installation:259 - VFDB Databases are missing.
# 2026-05-05 05:19:26.626 | INFO     | databases:check_db_installation:266 - CARD Databases are missing.
# 2026-05-05 05:19:26.626 | INFO     | databases:check_db_installation:272 - PHROGs Annotation File is missing.
# 2026-05-05 05:19:26.627 | INFO     | databases:check_db_installation:278 - INPHARED Mash Annotation File is missing.
# 2026-05-05 05:19:26.627 | INFO     | databases:check_db_installation:284 - INPHARED Mash Sketch File is missing.
# 2026-05-05 05:19:26.627 | INFO     | databases:instantiate_install:129 - Some Databases are missing.
# 2026-05-05 05:19:26.627 | INFO     | databases:instantiate_install:134 - Downloading Pharokka Databases from https://zenodo.org/record/17110353/files/pharokka_v1.8.0_databases.tar.gz.
#
# 2026-05-05 05:20:17.460 | INFO     | databases:instantiate_install:145 - Database file download OK: a63c485241b900a11989bd1821bfbb09
# 2026-05-05 05:20:17.461 | INFO     | databases:instantiate_install:151 - Extracting DB tarball: file=pharokka_db/pharokka_v1.8.0_databases.tar.gz, output=pharokka_db
# Downloading phold database. This will take a few minutes. Please be patient :)
# 2026-05-05 05:20:44.234 | INFO     | phold:install:1343 - You have specified the phold_db directory to store the Phold database and ProstT5 model
# 2026-05-05 05:20:44.234 | INFO     | phold:install:1355 - Checking that the Rostlab/ProstT5_fp16 ProstT5 model is available in phold_db
# 2026-05-05 05:20:44.238 | INFO     | phold.features.predict_3Di:get_T5_model:125 - Using device: cpu
# 2026-05-05 05:20:44.238 | INFO     | phold.features.predict_3Di:get_T5_model:131 - Loading T5 from: phold_db/Rostlab/ProstT5_fp16
# 2026-05-05 05:20:44.238 | INFO     | phold.features.predict_3Di:get_T5_model:132 - If phold_db/Rostlab/ProstT5_fp16 is not found, it will be downloaded
# 2026-05-05 05:20:44.238 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/refs/main does not exist.
# 2026-05-05 05:20:44.238 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/2c19eb6e3b583f52d34b903b5978d3d30b6b7682 does not exist.
# 2026-05-05 05:20:44.238 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/60fe6bb247c90b8545d7b73820cd796ce6dcbd59 does not exist.
# 2026-05-05 05:20:44.239 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/6fc7be92c58e238f20a6cdea5a87b123a4ad35e2 does not exist.
# 2026-05-05 05:20:44.239 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/74da7b4afcde53faa570114b530c726135bdfcdb813dec3abfb27f9d44db7324 does not exist.
# 2026-05-05 05:20:44.239 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/b1a9ffcef73280cc57f090ad6446b4116b574b6c75d83ccc32778282f7f00855 does not exist.
# 2026-05-05 05:20:44.239 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/e9322396e6e75ecf8da41a9527e24dfa4eeea505 does not exist.
# 2026-05-05 05:20:44.239 | INFO     | phold.features.predict_3Di:get_T5_model:142 - ProstT5 not found. Downloading ProstT5 from Hugging Face
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-05-05 05:21:33.163 | INFO     | phold.features.predict_3Di:get_T5_model:174 - Rostlab/ProstT5_fp16 loaded
# 2026-05-05 05:21:33.291 | INFO     | phold:install:1366 - ProstT5 model downloaded
# 2026-05-05 05:21:33.291 | INFO     | phold.databases.db:install_database:143 - Checking Phold database installation in phold_db.
# 2026-05-05 05:21:33.292 | WARNING  | phold.databases.db:check_db_installation:430 - Phold Database file phold_db/acrs_plddt_over_70_metadata.tsv is missing
# 2026-05-05 05:21:33.292 | WARNING  | phold.databases.db:check_db_installation:439 - Phold Foldseek-GPU Database file phold_db/all_phold_structures_gpu is missing
# 2026-05-05 05:21:33.292 | INFO     | phold.databases.db:install_database:148 - Some Phold databases files are missing
# 2026-05-05 05:21:33.292 | INFO     | phold.databases.db:install_database:158 - Downloading Phold Search DB 1.36M from https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz
# 2026-05-05 05:21:33.292 | INFO     | phold.utils.external_tools:run_stream:56 - Started running aria2c --dir phold_db --out phold_search_db_v_1_0_0.tar.gz --max-connection-per-server=8 --allow-overwrite=true https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz ...
#
# 05/05 05:21:33 [NOTICE] Downloading 1 item(s)
# [#f2d933 96KiB/1.7GiB(0%) CN:5 DL:233KiB ETA:2h12m32s]
# [#f2d933 12MiB/1.7GiB(0%) CN:5 DL:8.6MiB ETA:3m28s]
# [#f2d933 35MiB/1.7GiB(1%) CN:5 DL:4.8MiB ETA:6m2s]
# [#f2d933 64MiB/1.7GiB(3%) CN:5 DL:7.8MiB ETA:3m42s]
# [#f2d933 68MiB/1.7GiB(3%) CN:5 DL:6.1MiB ETA:4m42s]
# [#f2d933 70MiB/1.7GiB(3%) CN:5 DL:5.4MiB ETA:5m18s]
# [#f2d933 118MiB/1.7GiB(6%) CN:5 DL:6.9MiB ETA:4m4s]
# [#f2d933 123MiB/1.7GiB(6%) CN:5 DL:6.6MiB ETA:4m13s]
# [#f2d933 125MiB/1.7GiB(6%) CN:5 DL:833KiB ETA:34m29s]
# [#f2d933 127MiB/1.7GiB(7%) CN:5 DL:634KiB ETA:45m15s]
# [#f2d933 128MiB/1.7GiB(7%) CN:5 DL:669KiB ETA:42m51s]
# [#f2d933 128MiB/1.7GiB(7%) CN:5 DL:458KiB ETA:1h2m32s]
# [#f2d933 130MiB/1.7GiB(7%) CN:5 DL:328KiB ETA:1h27m22s]
# [#f2d933 130MiB/1.7GiB(7%) CN:5 DL:162KiB ETA:2h55m59s]
# [#f2d933 132MiB/1.7GiB(7%) CN:5 DL:241KiB ETA:1h58m25s]
# [#f2d933 149MiB/1.7GiB(8%) CN:5 DL:2.0MiB ETA:13m36s]
# [#f2d933 197MiB/1.7GiB(10%) CN:5 DL:11MiB ETA:2m23s]
# [#f2d933 256MiB/1.7GiB(14%) CN:5 DL:18MiB ETA:1m25s]
# [#f2d933 275MiB/1.7GiB(15%) CN:5 DL:21MiB ETA:1m12s]
# [#f2d933 276MiB/1.7GiB(15%) CN:5 DL:18MiB ETA:1m25s]
# [#f2d933 321MiB/1.7GiB(17%) CN:5 DL:20MiB ETA:1m11s]
#  *** Download Progress Summary as of Tue May  5 05:22:36 2026 ***
# ===============================================================================
# [#f2d933 322MiB/1.7GiB(17%) CN:5 DL:6.4MiB ETA:3m50s]
# FILE: phold_db/phold_search_db_v_1_0_0.tar.gz
# -------------------------------------------------------------------------------
#
# [#f2d933 322MiB/1.7GiB(17%) CN:5 DL:6.4MiB ETA:3m50s]
# [#f2d933 341MiB/1.7GiB(18%) CN:5 DL:7.9MiB ETA:3m3s]
# [#f2d933 347MiB/1.7GiB(19%) CN:5 DL:0B]
# [#f2d933 347MiB/1.7GiB(19%) CN:5 DL:517KiB ETA:48m16s]
# [#f2d933 351MiB/1.7GiB(19%) CN:5 DL:1.4MiB ETA:16m46s]
# [#f2d933 351MiB/1.7GiB(19%) CN:5 DL:1.0MiB ETA:22m10s]
# [#f2d933 352MiB/1.7GiB(19%) CN:5 DL:835KiB ETA:29m48s]
# [#f2d933 356MiB/1.7GiB(19%) CN:5 DL:1.2MiB ETA:19m10s]
# [#f2d933 356MiB/1.7GiB(19%) CN:5 DL:1.1MiB ETA:21m59s]
# [#f2d933 357MiB/1.7GiB(19%) CN:5 DL:695KiB ETA:35m38s]
# [#f2d933 361MiB/1.7GiB(19%) CN:5 DL:1.0MiB ETA:22m16s]
# [#f2d933 361MiB/1.7GiB(19%) CN:5 DL:586KiB ETA:42m11s]
# [#f2d933 382MiB/1.7GiB(21%) CN:5 DL:2.9MiB ETA:8m10s]
# [#f2d933 391MiB/1.7GiB(21%) CN:5 DL:3.5MiB ETA:6m37s]
# [#f2d933 398MiB/1.7GiB(22%) CN:5 DL:5.3MiB ETA:4m21s]
# [#f2d933 401MiB/1.7GiB(22%) CN:5 DL:5.0MiB ETA:4m41s]
# [#f2d933 401MiB/1.7GiB(22%) CN:5 DL:4.9MiB ETA:4m46s]
# [#f2d933 435MiB/1.7GiB(24%) CN:5 DL:8.0MiB ETA:2m51s]
# [#f2d933 443MiB/1.7GiB(24%) CN:5 DL:9.4MiB ETA:2m25s]
# [#f2d933 446MiB/1.7GiB(24%) CN:5 DL:6.8MiB ETA:3m20s]
# [#f2d933 447MiB/1.7GiB(24%) CN:5 DL:5.4MiB ETA:4m8s]
# [#f2d933 478MiB/1.7GiB(26%) CN:5 DL:7.9MiB ETA:2m46s]
# [#f2d933 489MiB/1.7GiB(27%) CN:5 DL:8.9MiB ETA:2m27s]
#  *** Download Progress Summary as of Tue May  5 05:23:40 2026 ***
# ===============================================================================
# [#f2d933 491MiB/1.7GiB(27%) CN:5 DL:5.4MiB ETA:4m]
# FILE: phold_db/phold_search_db_v_1_0_0.tar.gz
# -------------------------------------------------------------------------------
#
# [#f2d933 491MiB/1.7GiB(27%) CN:5 DL:5.4MiB ETA:4m]
# [#f2d933 519MiB/1.7GiB(28%) CN:5 DL:7.9MiB ETA:2m42s]
# [#f2d933 540MiB/1.7GiB(29%) CN:5 DL:8.0MiB ETA:2m37s]
# [#f2d933 568MiB/1.7GiB(31%) CN:5 DL:10MiB ETA:1m55s]
# [#f2d933 583MiB/1.7GiB(32%) CN:5 DL:11MiB ETA:1m50s]
# [#f2d933 588MiB/1.7GiB(32%) CN:5 DL:10MiB ETA:1m59s]
# [#f2d933 591MiB/1.7GiB(32%) CN:5 DL:0B]
# [#f2d933 591MiB/1.7GiB(32%) CN:5 DL:207KiB ETA:1h40m3s]
# [#f2d933 593MiB/1.7GiB(32%) CN:5 DL:1.1MiB ETA:17m29s]
# [#f2d933 593MiB/1.7GiB(32%) CN:5 DL:788KiB ETA:26m19s]
# [#f2d933 594MiB/1.7GiB(32%) CN:5 DL:782KiB ETA:26m30s]
# [#f2d933 596MiB/1.7GiB(32%) CN:5 DL:890KiB ETA:23m16s]
# [#f2d933 596MiB/1.7GiB(32%) CN:5 DL:814KiB ETA:25m25s]
# [#f2d933 598MiB/1.7GiB(33%) CN:5 DL:0.9MiB ETA:21m8s]
# [#f2d933 598MiB/1.7GiB(33%) CN:5 DL:886KiB ETA:23m19s]
# [#f2d933 599MiB/1.7GiB(33%) CN:5 DL:873KiB ETA:23m38s]
# [#f2d933 600MiB/1.7GiB(33%) CN:5 DL:821KiB ETA:25m6s]
# [#f2d933 601MiB/1.7GiB(33%) CN:5 DL:876KiB ETA:23m32s]
# [#f2d933 603MiB/1.7GiB(33%) CN:5 DL:0.9MiB ETA:20m26s]
# [#f2d933 604MiB/1.7GiB(33%) CN:5 DL:888KiB ETA:23m10s]
# [#f2d933 636MiB/1.7GiB(35%) CN:5 DL:4.3MiB ETA:4m27s]
# [#f2d933 685MiB/1.7GiB(37%) CN:5 DL:8.9MiB ETA:2m5s]
# [#f2d933 738MiB/1.7GiB(40%) CN:5 DL:14MiB ETA:1m16s]
# [#f2d933 793MiB/1.7GiB(43%) CN:5 DL:19MiB ETA:51s]
# [#f2d933 846MiB/1.7GiB(46%) CN:5 DL:25MiB ETA:37s]
# [#f2d933 901MiB/1.7GiB(49%) CN:5 DL:31MiB ETA:28s]
#  *** Download Progress Summary as of Tue May  5 05:25:02 2026 ***
# ===============================================================================
# [#f2d933 0.9GiB/1.7GiB(52%) CN:5 DL:0B]
# FILE: phold_db/phold_search_db_v_1_0_0.tar.gz
# -------------------------------------------------------------------------------
#
# [#f2d933 0.9GiB/1.7GiB(52%) CN:5 DL:0B]
# [#f2d933 0.9GiB/1.7GiB(52%) CN:5 DL:0B]
# [#f2d933 0.9GiB/1.7GiB(54%) CN:5 DL:28MiB ETA:29s]
# [#f2d933 1.0GiB/1.7GiB(56%) CN:5 DL:40MiB ETA:19s]
# [#f2d933 1.0GiB/1.7GiB(60%) CN:5 DL:46MiB ETA:15s]
# [#f2d933 1.1GiB/1.7GiB(63%) CN:5 DL:49MiB ETA:13s]
# [#f2d933 1.1GiB/1.7GiB(66%) CN:5 DL:52MiB ETA:11s]
# [#f2d933 1.2GiB/1.7GiB(70%) CN:5 DL:53MiB ETA:10s]
# [#f2d933 1.2GiB/1.7GiB(72%) CN:5 DL:51MiB ETA:9s]
# [#f2d933 1.2GiB/1.7GiB(72%) CN:5 DL:0B]
# [#f2d933 1.2GiB/1.7GiB(72%) CN:5 DL:183KiB ETA:45m50s]
# [#f2d933 1.2GiB/1.7GiB(72%) CN:5 DL:524KiB ETA:16m]
# [#f2d933 1.2GiB/1.7GiB(72%) CN:5 DL:668KiB ETA:12m29s]
# [#f2d933 1.2GiB/1.7GiB(72%) CN:5 DL:531KiB ETA:15m41s]
# [#f2d933 1.2GiB/1.7GiB(73%) CN:5 DL:101KiB ETA:1h22m6s]
#  *** Download Progress Summary as of Tue May  5 05:26:03 2026 ***
# ===============================================================================
# [#f2d933 1.2GiB/1.7GiB(73%) CN:5 DL:303KiB ETA:27m22s]
# FILE: phold_db/phold_search_db_v_1_0_0.tar.gz
# -------------------------------------------------------------------------------
#
# [#f2d933 1.2GiB/1.7GiB(73%) CN:5 DL:303KiB ETA:27m22s]
# [#f2d933 1.2GiB/1.7GiB(73%) CN:5 DL:0B]
# [#f2d933 1.3GiB/1.7GiB(74%) CN:5 DL:25MiB ETA:18s]
# [#f2d933 1.3GiB/1.7GiB(77%) CN:5 DL:40MiB ETA:9s]
# [#f2d933 1.4GiB/1.7GiB(81%) CN:5 DL:48MiB ETA:6s]
# [#f2d933 1.4GiB/1.7GiB(84%) CN:5 DL:50MiB ETA:5s]
# [#f2d933 1.5GiB/1.7GiB(87%) CN:5 DL:53MiB ETA:4s]
# [#f2d933 1.6GiB/1.7GiB(91%) CN:5 DL:54MiB ETA:2s]
# [#f2d933 1.6GiB/1.7GiB(94%) CN:5 DL:54MiB ETA:1s]
# [#f2d933 1.7GiB/1.7GiB(96%) CN:5 DL:52MiB ETA:1s]
# [#f2d933 1.7GiB/1.7GiB(98%) CN:2 DL:51MiB]
# [#f2d933 1.7GiB/1.7GiB(99%) CN:1 DL:50MiB]
#
# 05/05 05:26:25 [NOTICE] Download complete: phold_db/phold_search_db_v_1_0_0.tar.gz
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f2d933|OK  |   6.2MiB/s|phold_db/phold_search_db_v_1_0_0.tar.gz
#
# Status Legend:
# (OK):download completed.
# 2026-05-05 05:26:25.177 | INFO     | phold.utils.external_tools:run_stream:73 - Done running aria2c --dir phold_db --out phold_search_db_v_1_0_0.tar.gz --max-connection-per-server=8 --allow-overwrite=true https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz
# 2026-05-05 05:26:30.630 | INFO     | phold.databases.db:install_database:171 - Phold database file download OK: ddbe0d94b1d94a392cfeb4ec113f4362
# 2026-05-05 05:26:30.630 | INFO     | phold.databases.db:install_database:177 - Extracting Phold database tarball: file=phold_db/phold_search_db_v_1_0_0.tar.gz, output=phold_db
# 2026-05-05 05:27:05.940 | INFO     | phold.databases.db:install_database:189 - Some Phold database files compatible with Foldseek-GPU are missing
# 2026-05-05 05:27:05.940 | INFO     | phold.databases.db:install_database:192 - Creating them
# 2026-05-05 05:27:05.941 | INFO     | phold.utils.external_tools:run:45 - Started running foldseek makepaddedseqdb phold_db/all_phold_structures phold_db/all_phold_structures_gpu ...
# 2026-05-05 05:27:30.344 | INFO     | phold.utils.external_tools:run:47 - Done running foldseek makepaddedseqdb phold_db/all_phold_structures phold_db/all_phold_structures_gpu
# Downloading phynteny database. This will take a few minutes. Please be patient :)
# /usr/local/lib/python3.12/site-packages/src/install_models.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Creating 'models' subdirectory in specified path
# Downloading Phynteny models to: /content/phynteny_models/models
# 2026-05-05 05:27:34.445 | INFO     | src.install_models:instantiate_install:51 - Model installation directory (absolute path): /content/phynteny_models/models
# 2026-05-05 05:27:34.445 | WARNING  | src.install_models:check_db_installation:93 - Phynteny models are missing.
# 2026-05-05 05:27:34.445 | INFO     | src.install_models:instantiate_install:61 - Some models are missing.
# 2026-05-05 05:27:34.445 | INFO     | src.install_models:get_model_zenodo:325 - Models will be installed to: /content/phynteny_models/models
# 2026-05-05 05:27:34.445 | INFO     | src.install_models:get_model_zenodo:331 - Downloading tarball to: /content/phynteny_models
# 2026-05-05 05:27:34.445 | INFO     | src.install_models:get_model_zenodo:341 - Downloading Phynteny Models from https://zenodo.org/records/17336733/files/phynteny_transformer_models_2025-06-03.tar.gz.
# 2026-05-05 05:27:34.445 | DEBUG    | src.install_models:get_model_zenodo:342 - path
# 2026-05-05 05:27:34.445 | DEBUG    | src.install_models:get_model_zenodo:343 - https://zenodo.org/records/17336733/files/phynteny_transformer_models_2025-06-03.tar.gz
# 2026-05-05 05:27:35.020 | INFO     | src.install_models:download:114 - Downloading file, total size: 222.05 MB
# Progress: 100.0% (222.0/222.0 MB)
# 2026-05-05 05:27:53.620 | INFO     | src.install_models:get_model_zenodo:350 - Phynteny Models tarball download OK: 511358aca216d214b5d7ca7a57fe2250
# 2026-05-05 05:27:53.620 | INFO     | src.install_models:get_model_zenodo:357 - Extracting Phynteny Models tarball: file=phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz, output=/content/phynteny_models/models
# 2026-05-05 05:27:53.621 | INFO     | src.install_models:untar:202 - Path checks: {'tarball_exists': True, 'tarball_readable': True, 'tarball_size': 232831570, 'output_exists': True, 'output_writable': True}
# 2026-05-05 05:27:55.125 | INFO     | src.install_models:untar:218 - Tarball inspection: {'status': 'success', 'file_count': 14, 'top_level_dirs': ['phynteny_transformer_models_2025-06-03'], 'sample_files': ['phynteny_transformer_models_2025-06-03', 'phynteny_transformer_models_2025-06-03/all_calibration_models.pkl', 'phynteny_transformer_models_2025-06-03/calibration_models.pkl', 'phynteny_transformer_models_2025-06-03/category_mapping.pkl', 'phynteny_transformer_models_2025-06-03/fold_10transformer.model']}
# 2026-05-05 05:27:55.126 | INFO     | src.install_models:untar:221 - Starting extraction: phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz to phynteny_models/models
# 2026-05-05 05:27:56.618 | INFO     | src.install_models:untar:225 - Found 14 items in tarball
# 2026-05-05 05:27:56.618 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03
# 2026-05-05 05:27:56.619 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/all_calibration_models.pkl
# 2026-05-05 05:27:56.622 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/calibration_models.pkl
# 2026-05-05 05:27:56.622 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/category_mapping.pkl
# 2026-05-05 05:27:56.622 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_10transformer.model
# 2026-05-05 05:27:56.792 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_1transformer.model
# 2026-05-05 05:27:56.965 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_2transformer.model
# 2026-05-05 05:27:57.143 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_3transformer.model
# 2026-05-05 05:27:57.356 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_4transformer.model
# 2026-05-05 05:27:57.576 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_5transformer.model
# 2026-05-05 05:27:57.820 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_6transformer.model
# 2026-05-05 05:27:58.000 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_7transformer.model
# 2026-05-05 05:27:58.186 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_8transformer.model
# 2026-05-05 05:27:58.373 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_9transformer.model
# 2026-05-05 05:27:58.544 | INFO     | src.install_models:untar:241 - Extraction completed
# 2026-05-05 05:27:58.545 | INFO     | src.install_models:untar:248 - Contents of output directory after extraction: ['phynteny_transformer_models_2025-06-03']
# 2026-05-05 05:27:58.545 | INFO     | src.install_models:untar:265 - Found potential model directories: ['phynteny_transformer_models_2025-06-03']
# 2026-05-05 05:27:58.545 | INFO     | src.install_models:untar:282 - Found 13 files to move from phynteny_models/models/phynteny_transformer_models_2025-06-03 to phynteny_models/models
# 2026-05-05 05:27:58.545 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_8transformer.model to phynteny_models/models/fold_8transformer.model
# 2026-05-05 05:27:58.545 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_4transformer.model to phynteny_models/models/fold_4transformer.model
# 2026-05-05 05:27:58.545 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_10transformer.model to phynteny_models/models/fold_10transformer.model
# 2026-05-05 05:27:58.545 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_2transformer.model to phynteny_models/models/fold_2transformer.model
# 2026-05-05 05:27:58.546 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_7transformer.model to phynteny_models/models/fold_7transformer.model
# 2026-05-05 05:27:58.546 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/calibration_models.pkl to phynteny_models/models/calibration_models.pkl
# 2026-05-05 05:27:58.546 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/all_calibration_models.pkl to phynteny_models/models/all_calibration_models.pkl
# 2026-05-05 05:27:58.546 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_6transformer.model to phynteny_models/models/fold_6transformer.model
# 2026-05-05 05:27:58.546 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_1transformer.model to phynteny_models/models/fold_1transformer.model
# 2026-05-05 05:27:58.546 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_9transformer.model to phynteny_models/models/fold_9transformer.model
# 2026-05-05 05:27:58.546 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_5transformer.model to phynteny_models/models/fold_5transformer.model
# 2026-05-05 05:27:58.546 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/category_mapping.pkl to phynteny_models/models/category_mapping.pkl
# 2026-05-05 05:27:58.547 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_3transformer.model to phynteny_models/models/fold_3transformer.model
# 2026-05-05 05:27:58.547 | INFO     | src.install_models:untar:295 - Successfully moved 13 files to phynteny_models/models
# 2026-05-05 05:27:58.547 | INFO     | src.install_models:untar:299 - Removing temporary directory: phynteny_models/models/phynteny_transformer_models_2025-06-03
# 2026-05-05 05:27:58.547 | INFO     | src.install_models:get_model_zenodo:363 - Keeping tarball at phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz
# 2026-05-05 05:27:58.547 | INFO     | src.install_models:get_model_zenodo:367 - Installed 10 model files
# 2026-05-05 05:27:58.547 | INFO     | src.install_models:get_model_zenodo:372 - Done.
# 2026-05-05 05:27:58.547 | INFO     | src.install_models:instantiate_install:63 - Models successfully downloaded to: /content/phynteny_models/models
#
# Installation Summary:
# ---------------------
# Models directory: /content/phynteny_models/models
# Model files installed: 10
# Confidence dictionary: Installed
#
# When running phynteny_transformer, use:
#   phynteny_transformer -m /content/phynteny_models/models [other options] INPUT_FILE
# CPU times: user 1.2 s, sys: 254 ms, total: 1.45 s
# Wall time: 8min 34s

# %%
#@title 4. Run Pharokka

#@markdown First, upload your phage(s) as a nucleotide input FASTA file

#@markdown Click on the folder icon to the left and use the file upload button.

#@markdown Once it is uploaded, write the file name in the INPUT_FILE field on the right.

#@markdown Then provide a directory for pharokka's output using PHAROKKA_OUT_DIR.
#@markdown The default is 'output_pharokka'.

#@markdown Then type in a gene prediction tool for pharokka.
#@markdown Please choose either 'phanotate', 'prodigal', or 'prodigal-gv'.

#@markdown You can also provide a prefix for your output files with PHAROKKA_PREFIX.
#@markdown If you provide nothing it will default to 'pharokka'.

#@markdown You can also provide a locus tag for your output files.
#@markdown If you provide nothing it will generate a random locus tag.

#@markdown You can click FAST to turn off --fast.
#@markdown By default it is True so that Pharokka runs faster in the Colab environment.

#@markdown You can click META to turn on --meta if you have multiple phages in your input.

#@markdown You can click META_HMM to turn on --meta_hmm.

#@markdown You can click FORCE to overwrite the output directory.
#@markdown This may be useful if your earlier pharokka run has crashed for whatever reason.

#@markdown The results of Pharokka will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHAROKKA_OUT_DIR.zip, where PHAROKKA_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import sys
import subprocess
import zipfile
INPUT_FILE = 'NG-A7284_JEP_119_RPS_JPAP003_libLAV4145_assembly.fasta' #@param {type:"string"}

if os.path.exists(INPUT_FILE):
    print(f"Input file {INPUT_FILE} exists")
else:
    print(f"Error: File {INPUT_FILE} does not exist")
    print(f"Please check the spelling and that you have uploaded it correctly")
    sys.exit(1)

PHAROKKA_OUT_DIR = 'RPS_JPAP003'  #@param {type:"string"}
GENE_PREDICTOR = 'phanotate'  #@param {type:"string"}
allowed_gene_predictors = ['phanotate', 'prodigal', 'prodigal-gv']
# Check if the input parameter is valid
if GENE_PREDICTOR.lower() not in allowed_gene_predictors:
    raise ValueError("Invalid GENE_PREDICTOR. Please choose from: 'phanotate', 'prodigal', 'prodigal-gv'.")

PHAROKKA_PREFIX = 'JPAP-003'  #@param {type:"string"}
LOCUS_TAG = 'Default'  #@param {type:"string"}
FAST = True  #@param {type:"boolean"}
META = False  #@param {type:"boolean"}
META_HMM = False  #@param {type:"boolean"}
FORCE = True  #@param {type:"boolean"}


# Construct the command
# need to suppress PYTHONWARNINGS for phanotate version handling
command = (
    f'pharokka.py -d pharokka_db -i {INPUT_FILE} -t 4 '
    f'-o {PHAROKKA_OUT_DIR} -p {PHAROKKA_PREFIX} -l {LOCUS_TAG} -g {GENE_PREDICTOR}'
)

if FORCE is True:
  command = f"{command} -f"

if FAST is True:
  command = f"{command} --fast"

if META is True:
  command = f"{command} -m"

if META_HMM is True:
  command = f"{command} --meta_hmm"

# Execute the command
try:
    print("Running pharokka")
    subprocess.run(command, shell=True, check=True)
    print("pharokka completed successfully.")
    print(f"Your output is in {PHAROKKA_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHAROKKA_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHAROKKA_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHAROKKA_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Input file NG-A7284_JEP_119_RPS_JPAP003_libLAV4145_assembly.fasta exists
# Running pharokka
# pharokka completed successfully.
# Your output is in RPS_JPAP003.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to RPS_JPAP003.zip
# CPU times: user 75 ms, sys: 3.09 ms, total: 78.1 ms
# Wall time: 1min 57s

# %%
#@title 5. Run phold

#@markdown This cell will run phold on the output of cell 3's Pharokka run

#@markdown You do not need to provide any further input files

#@markdown You can now provide a directory for phold's output with PHOLD_OUT_DIR.
#@markdown The default is 'output_phold'.

#@markdown You can also provide a prefix for your output files with PHOLD_PREFIX.
#@markdown If you provide nothing it will default to 'phold'.

#@markdown You can click FORCE to overwrite the output directory with .
#@markdown This may be useful if your earlier phold run has crashed for whatever reason.

#@markdown If your input has multiple phages, you can click SEPARATE.
#@markdown This will output separate GenBank files in the output directory.

#@markdown The results of Phold will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHOLD_OUT_DIR.zip, where PHOLD_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import subprocess
import zipfile

# phold input is pharokka output
PHOLD_INPUT = f"{PHAROKKA_OUT_DIR}/{PHAROKKA_PREFIX}.gbk"
PHOLD_OUT_DIR = 'RPS_JPAP003_phold'  #@param {type:"string"}
PHOLD_PREFIX = 'RPS_JPAP003'  #@param {type:"string"}
FORCE = True  #@param {type:"boolean"}
SEPARATE = False  #@param {type:"boolean"}

# Construct the command
command = f"phold run -i {PHOLD_INPUT} -t 4 -o {PHOLD_OUT_DIR} -p {PHOLD_PREFIX} -d phold_db --foldseek_gpu"

if FORCE is True:
  command = f"{command} -f"
if SEPARATE is True:
  command = f"{command} --separate"


# Execute the command
try:
    print("Running phold")
    subprocess.run(command, shell=True, check=True)
    print("phold completed successfully.")
    print(f"Your output is in {PHOLD_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHOLD_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHOLD_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHOLD_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Running phold
# phold completed successfully.
# Your output is in RPS_JPAP003_phold.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to RPS_JPAP003_phold.zip
# CPU times: user 44.3 ms, sys: 5.07 ms, total: 49.4 ms
# Wall time: 1min 41s

# %%
#@title 6. Run Phynteny

#@markdown This cell will run phynteny on the output of cell 5's Phold run to predict the function of remaining hypothetical proteins

#@markdown You do not need to provide any further input files

#@markdown You can now provide a directory for phynteny's output with PHYNTENY_OUT_DIR.
#@markdown The default is 'output_phynteny'.

#@markdown You can click FORCE to overwrite the output directory with .
#@markdown This may be useful if your phynteny run has crashed for whatever reason.

#@markdown The results of Phynteny will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHYNTENY_OUT_DIR.zip, where PHYNTENY_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import subprocess
import zipfile

# phynteny input is pharokka output
PHYNTENY_INPUT = f"{PHOLD_OUT_DIR}/{PHOLD_PREFIX}.gbk"
PHYNTENY_OUT_DIR = 'RPS_JPAP003_phynteny'  #@param {type:"string"}
FORCE = False  #@param {type:"boolean"}

# Construct the command
command = f"phynteny_transformer -m  /content/phynteny_models/models -o {PHYNTENY_OUT_DIR} {PHYNTENY_INPUT}"
if FORCE is True:
  command = f"{command} -f"


# Execute the command
try:
    print("Running phynteny")
    subprocess.run(command, shell=True, check=True)
    print("phynteny completed successfully.")
    print(f"Your output is in {PHYNTENY_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHYNTENY_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHYNTENY_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHYNTENY_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Running phynteny
# phynteny completed successfully.
# Your output is in RPS_JPAP003_phynteny.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to RPS_JPAP003_phynteny.zip
# CPU times: user 56.4 ms, sys: 1.76 ms, total: 58.2 ms
# Wall time: 54.7 s
